# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('F:\Projects\machineLearningFundamental\datasets\DogsOfZurich.csv')

# %%
df.head()
# Out:
#    DOG ID OWNER AGE OWNER GENDER  CITY DISTRICT  NEIGHBORHOOD
# 0     126     61-70            m            9.0          92.0  \
# 1     171     61-70            m            3.0          31.0
# 2     574     61-70            w            2.0          23.0
# 3     695     41-50            m            6.0          63.0
# 4     893     61-70            w            7.0          71.0
#
#         PRIMARY BREED SECONDARY BREED  DOG BIRTH YEAR DOG GENDER
# 0       Welsh Terrier             NaN            2011          w  \
# 1   Berner Sennenhund             NaN            2009          m
# 2     Mischling gross             NaN            2013          w
# 3  Labrador Retriever             NaN            2012          w
# 4     Mittelschnauzer             NaN            2010          w
#
#        DOG COLOR
# 0  schwarz/braun
# 1       tricolor
# 2        schwarz
# 3          braun
# 4        schwarz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7155 entries, 0 to 7154
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DOG ID           7155 non-null   int64
#  1   OWNER AGE        7154 non-null   object
#  2   OWNER GENDER     7155 non-null   object
#  3   CITY DISTRICT    7154 non-null   float64
#  4   NEIGHBORHOOD     7154 non-null   float64
#  5   PRIMARY BREED    7155 non-null   object
#  6   SECONDARY BREED  543 non-null    object
#  7   DOG BIRTH YEAR   7155 non-null   int64
#  8   DOG GENDER       7155 non-null   object
#  9   DOG COLOR        7155 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 559.1+ KB

# %%
df.describe()
# Out:
#               DOG ID  CITY DISTRICT  NEIGHBORHOOD  DOG BIRTH YEAR
# count    7155.000000    7154.000000   7154.000000     7155.000000
# mean   105854.243326       7.413195     76.695834     2009.803215
# std     21260.952718       3.261187     33.025614        4.115384
# min       126.000000       1.000000      4.000000     1996.000000
# 25%     88587.500000       5.000000     51.000000     2007.000000
# 50%    105784.000000       8.000000     81.000000     2010.000000
# 75%    124634.500000      10.000000    102.000000     2013.000000
# max    135731.000000      12.000000    123.000000     2017.000000

# %%
(df.isna().sum()/len(df))*100
# Out:
# DOG ID              0.000000
# OWNER AGE           0.013976
# OWNER GENDER        0.000000
# CITY DISTRICT       0.013976
# NEIGHBORHOOD        0.013976
# PRIMARY BREED       0.000000
# SECONDARY BREED    92.410901
# DOG BIRTH YEAR      0.000000
# DOG GENDER          0.000000
# DOG COLOR           0.000000
# dtype: float64

# %%
df.nunique()
# Out:
# DOG ID             6448
# OWNER AGE             9
# OWNER GENDER          2
# CITY DISTRICT        12
# NEIGHBORHOOD         36
# PRIMARY BREED       304
# SECONDARY BREED     118
# DOG BIRTH YEAR       22
# DOG GENDER            2
# DOG COLOR           169
# dtype: int64

# %%
df.hist(bins=100)
# Out:
# array([[<Axes: title={'center': 'DOG ID'}>,
#         <Axes: title={'center': 'CITY DISTRICT'}>],
#        [<Axes: title={'center': 'NEIGHBORHOOD'}>,
#         <Axes: title={'center': 'DOG BIRTH YEAR'}>]], dtype=object)

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['OWNER AGE', 'OWNER GENDER', 'PRIMARY BREED', 'SECONDARY BREED',
#        'DOG GENDER', 'DOG COLOR'],
#       dtype='object')

# %%
plt.title('DOG COLOR')
sns.countplot(data=df, x='DOG COLOR')
# Out:
# <Axes: title={'center': 'DOG COLOR'}, xlabel='DOG COLOR', ylabel='count'>

# %%
for color in df['DOG COLOR'].unique():
    leng = len(df[df['DOG COLOR'] == color])
    if leng > 350:
        print(f'{color} have {leng}')
# Out:
# schwarz/braun have 371
# tricolor have 696
# schwarz have 777
# braun have 536
# schwarz/weiss have 458
# weiss have 581

# %%
plt.title('DOG GENDER')
sns.countplot(data=df, x='DOG GENDER')
# Out:
# <Axes: title={'center': 'DOG GENDER'}, xlabel='DOG GENDER', ylabel='count'>

# %%
plt.title('OWNER GENDER')
sns.countplot(data=df, x='OWNER GENDER')
# Out:
# <Axes: title={'center': 'OWNER GENDER'}, xlabel='OWNER GENDER', ylabel='count'>

# %%
sns.countplot(data=df, x='OWNER GENDER', hue='DOG GENDER')
# Out:
# <Axes: xlabel='OWNER GENDER', ylabel='count'>

# %%
df['OWNER AGE'].unique()
# Out:
# array(['61-70', '41-50', '51-60', '71-80', '81-90', '31-40', '91-100',
#        '21-30', nan, '20-Nov'], dtype=object)
